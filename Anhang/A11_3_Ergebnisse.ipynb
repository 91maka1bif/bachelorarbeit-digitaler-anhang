# %%
# %run gat_dgl/gat.py --use-norm --use-labels --n-runs 1
# Out:
# Using backend: pytorch
# Namespace(amp=2, attn_drop=0.05, cpu=False, dropout=0.75, gpu=0, log_every=20, lr=0.002, m=3, n_epochs=2000, n_heads=3, n_hidden=256, n_layers=3, n_runs=1, plot_curves=False, step_size=0.001, use_labels=True, use_norm=True, vanilla=False, wd=0)
# Total edges before adding self-loop 2332486
# Total edges after adding self-loop 2501829
# Run: 1/1, Epoch: 20/2000
# Loss: 0.3566, Acc: 0.7181
# Train/Val/Test loss: 0.6237/1.0656/1.1993
# Train/Val/Test/Best val/Best test acc: 0.7962/0.6469/0.5975/0.6784/0.6780
# Run: 1/1, Epoch: 40/2000
# Loss: 0.3192, Acc: 0.7562
# Train/Val/Test loss: 0.7787/1.4627/1.7152
# Train/Val/Test/Best val/Best test acc: 0.7588/0.5555/0.4839/0.7183/0.6912
# Run: 1/1, Epoch: 60/2000
# Loss: 0.3003, Acc: 0.7733
# Train/Val/Test loss: 0.5079/0.8937/0.9991
# Train/Val/Test/Best val/Best test acc: 0.8341/0.7035/0.6655/0.7252/0.7181
# Run: 1/1, Epoch: 80/2000
# Loss: 0.2923, Acc: 0.7780
# Train/Val/Test loss: 0.5074/0.8514/0.8380
# ...
