# %%
# %run gat/gat.py --use-norm --n-runs 1
# Out:
# Using backend: pytorch
# Total edges before adding self-loop 2332486
# Total edges after adding self-loop 2501829
# [768, 768, 98304, 768, 768, 589824, 120, 120, 92160, 98304, 589824, 92160, 768, 768, 768, 768, 40]
# 1567000
# Run: 1/1, Epoch: 20/2000
# Loss: 1.2098, Acc: 0.6020
# Train/Val/Test loss: 1.6167/1.6769/1.7298
# Train/Val/Test/Best val/Best test acc: 0.6017/0.6097/0.5870/0.6097/0.5870
# Run: 1/1, Epoch: 40/2000
# Loss: 1.0786, Acc: 0.6410
# Train/Val/Test loss: 1.0740/1.0961/1.1833
# Train/Val/Test/Best val/Best test acc: 0.6548/0.6412/0.6072/0.6497/0.6634
# Run: 1/1, Epoch: 60/2000
# Loss: 0.9953, Acc: 0.6674
# Train/Val/Test loss: 0.9483/0.9157/0.8895
# Train/Val/Test/Best val/Best test acc: 0.6830/0.6904/0.7005/0.6904/0.7005
# Run: 1/1, Epoch: 80/2000
# Loss: 0.9437, Acc: 0.6870
# Train/Val/Test loss: 0.8964/0.8946/0.9278
# Train/Val/Test/Best val/Best test acc: 0.7015/0.6987/0.6852/0.7065/0.6952
# Run: 1/1, Epoch: 100/2000
# Loss: 0.9359, Acc: 0.6917
# ...

# %%
# %run run_experiments.py --dataset arxiv --method gat

# %%
# %run gat/gat.py --use-norm --n-runs 1
# Out:
# Using backend: pytorch
# Total edges before adding self-loop 2332486
# Total edges after adding self-loop 2501829
# [768, 768, 98304, 768, 768, 589824, 120, 120, 92160, 98304, 589824, 92160, 768, 768, 768, 768, 40]
# 1567000
# Run: 1/1, Epoch: 20/2000
# Loss: 1.2009, Acc: 0.6035
# Train/Val/Test loss: 1.6103/1.6665/1.7424
# Train/Val/Test/Best val/Best test acc: 0.5805/0.5765/0.5267/0.5765/0.5267
# Run: 1/1, Epoch: 40/2000
# Loss: 1.0752, Acc: 0.6438
# Train/Val/Test loss: 1.1206/1.1481/1.2668
# Train/Val/Test/Best val/Best test acc: 0.6299/0.6123/0.5636/0.6378/0.6536
# Run: 1/1, Epoch: 60/2000
# Loss: 1.0312, Acc: 0.6587
# Train/Val/Test loss: 0.9497/0.9978/1.1082
# Train/Val/Test/Best val/Best test acc: 0.6853/0.6631/0.6178/0.6747/0.6791
# Run: 1/1, Epoch: 80/2000
# Loss: 0.9429, Acc: 0.6874
# Train/Val/Test loss: 0.9336/0.9980/1.1117
# Train/Val/Test/Best val/Best test acc: 0.6873/0.6587/0.6130/0.6995/0.7064
# Run: 1/1, Epoch: 100/2000
# Loss: 0.9237, Acc: 0.6945
# ...
