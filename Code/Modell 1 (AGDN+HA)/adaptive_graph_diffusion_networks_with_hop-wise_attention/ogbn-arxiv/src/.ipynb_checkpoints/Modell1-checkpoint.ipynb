# %%
# %run gat-ha.py --seed 0 --n-label-iters 0 --lr 0.002 --n-layers 3 --n-hidden 256 --K 3 --n-heads 1 --dropout 0.5 --input_drop 0.1 --edge_drop 0.0 --attn_drop 0.05 --norm gcn --no-attn-dst --n-epochs 2000 --n-runs 1 --use-labels
# Out:
# Using backend: pytorch
# 2021-07-02 22:26:14,941 - DEBUG - Total edges before adding self-loop 2332486
# 2021-07-02 22:26:14,972 - DEBUG - Total edges after adding self-loop 2501829
# /home/student/3 AGDN (GAT-HA+3_heads+labels)/adaptive_graph_diffusion_networks_with_hop-wise_attention/ogbn-arxiv/src/models.py:516: UserWarning: nn.init.uniform is now deprecated in favor of nn.init.uniform_.
#   nn.init.uniform(self.sigma)
# 2021-07-02 22:35:10,741 - INFO - Run: 1/1, Epoch: 20/2000
# 2021-07-02 22:35:10,742 - INFO - Time: 26.5505, Loss: 0.9403, Acc: 0.7757
# 2021-07-02 22:35:10,743 - INFO - Train/Val/Test loss: 0.4360/0.9888/1.0186
# 2021-07-02 22:35:10,743 - INFO - Train/Val/Test/Best val/Best test acc: 0.8799/0.7002/0.6980/0.7002/0.6980
# 2021-07-02 22:35:10,744 - INFO - model sigma: [0.8894830942153931, 0.5251290202140808, 0.7518839836120605]
# 2021-07-02 22:35:19,241 - INFO - Run: 1/1, Epoch: 40/2000
# 2021-07-02 22:35:19,243 - INFO - Time: 13.4876, Loss: 0.8664, Acc: 0.8086
# ...

# %%
# %run gat-ha.py --seed 0 --n-label-iters 0 --lr 0.002 --n-layers 3 --n-hidden 256 --K 3 --n-heads 1 --dropout 0.5 --input_drop 0.1 --edge_drop 0.0 --attn_drop 0.05 --norm gcn --no-attn-dst --n-epochs 2000 --n-runs 1 --use-labels
# Out:
# Using backend: pytorch
# 2021-07-05 23:08:54,169 - DEBUG - Total edges before adding self-loop 2332486
# 2021-07-05 23:08:54,198 - DEBUG - Total edges after adding self-loop 2501829
# /home/student/3 AGDN (GAT-HA+3_heads+labels)/adaptive_graph_diffusion_networks_with_hop-wise_attention/ogbn-arxiv/src/models.py:516: UserWarning: nn.init.uniform is now deprecated in favor of nn.init.uniform_.
#   nn.init.uniform(self.sigma)
# 2021-07-05 23:17:12,606 - INFO - Run: 1/1, Epoch: 20/2000
# 2021-07-05 23:17:12,607 - INFO - Time: 24.6821, Loss: 0.9380, Acc: 0.7765
# 2021-07-05 23:17:12,607 - INFO - Train/Val/Test loss: 0.4393/0.9927/1.0193
# 2021-07-05 23:17:12,608 - INFO - Train/Val/Test/Best val/Best test acc: 0.8783/0.6982/0.6966/0.6982/0.6966
# 2021-07-05 23:17:12,609 - INFO - model sigma: [0.8894830942153931, 0.5251290202140808, 0.7518839836120605]
# 2021-07-05 23:17:21,174 - INFO - Run: 1/1, Epoch: 40/2000
# 2021-07-05 23:17:21,175 - INFO - Time: 12.5552, Loss: 0.8638, Acc: 0.8088
# ...
